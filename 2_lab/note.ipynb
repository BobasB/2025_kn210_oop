# %% [markdown]
# # Основи Python
# ## Знайомство з типами даних

# %% [markdown]
# ### Що таке типи даних у Python? (в редації АІ)
#
# **Типи даних** — це категорії, до яких належать всі значення у Python. Вони визначають, які операції можна виконувати над цими значеннями та як вони зберігаються в пам’яті.
#
# #### Основні типи даних у Python:
#
# 1. **int** — цілі числа
#    Наприклад: `5`, `-10`, `0`
#    Використовується для зберігання цілих чисел.
#
# 2. **float** — числа з плаваючою комою
#    Наприклад: `3.14`, `-0.001`, `2.0`
#    Використовується для зберігання дійсних чисел.
#
# 3. **bool** — логічний тип
#    Може приймати лише два значення: `True` або `False`.
#    Використовується для логічних операцій.
#
# 4. **str** — рядки (текст)
#    Наприклад: `"Привіт"`, `'Python'`
#    Використовується для зберігання текстової інформації.
#
# 5. **list** — список
#    Наприклад: `[1, 2, 3]`, `['a', 'b', 'c']`
#    Зберігає впорядковану змінювану послідовність елементів.
#
# 6. **tuple** — кортеж
#    Наприклад: `(1, 2, 3)`, `('a', 'b')`
#    Зберігає впорядковану незмінювану послідовність елементів.
#
# 7. **dict** — словник
#    Наприклад: `{'ім'я': 'Олег', 'вік': 20}`
#    Зберігає пари "ключ-значення".
#
# 8. **set** — множина
#    Наприклад: `{1, 2, 3}`
#    Зберігає унікальні, невпорядковані елементи.
#
# ---
#
# Кожен тип даних має свої особливості та використовується для вирішення різних задач у програмуванні.

# %% [markdown]
# ### Розглянемо стрічки str

# %%
s1 = "HellO"
s2 = 'World'
s3 = """Це стрічка яка може бути
перенесена на інший рядок"""
print(s1, "|Це вивід стрічки без змінної|", s2, s3)
s4 = "123" # Це також стрічка а не число
s5 = str(123) # Це також стрічка перетворена на число в явному вигляді
print("Типи змінних:", type(s4), type(s5))
# Out:
# HellO |Це вивід стрічки без змінної| World Це стрічка яка може бути
# перенесена на інший рядок
# Типи змінних: <class 'str'> <class 'str'>

# %% [markdown]
# >  особливості роботи з стрічками
# - ми можемо працювати з цілою стрічкою або розкласти її на окремі елементи
# - або навіть зробити слайси (частинки)
# - все в Python є обєктами і стрічки також

# %%
words = s3.split() # Розбиває стрічку на список слів
print(words)
print(s1[0:2], s1[2:4], s2[-2:]) # Слайси - частинки стрічки
# використання . до будь-якої змінної - це виклик методів обєкта
print(s1.lower(), s2.upper(), s4.isdigit()) # Методи стрічок
# Out:
# ['Це', 'стрічка', 'яка', 'може', 'бути', 'перенесена', 'на', 'інший', 'рядок']
# He ll ld
# hello WORLD True

# %% [markdown]
# ### Розглянемо цифри int float
# - Python є слабо типізованою мовою, що означає, сам Python визначає до якого типу петворити значення

# %%
i1 = 123 # Це ціле число
i2 = int("123") # Це також ціле, яке задано стрічкою але пертворено в int
i3 = int(12) # Це також ціле число, яке задано безпосередньо
i4: int = 123.45 # Це також ціле число, але з підказкою типу
print("Цілі числа:", i1, i2, i3, i4, type(i1), type(i2), type(i3), type(i4))
# Out:
# Цілі числа: 123 123 12 123.45 <class 'int'> <class 'int'> <class 'int'> <class 'float'>

# %% [markdown]
# ## Вчимо колекції (набори даних)
# - ми назвали це набором тому що ми можемо обєднувати різні типи даних, як прості стрічки, числа чи навіть самі колеції у єдине ціле
# - починаємо з списків (list) який є mutable колекцією

# %%
def func():
    pass

list_1 = [1, 2.0, 3, "hello", 4.5, [5, 6, 7], None, func]
list_1.append("new item")
list_1.remove(2.0)
list_1.pop(3)
print(list_1)
print(list_1[0:3]) # слайс з 0 по 2 індекс
# індексування
list_1[3][-1] = "world"
print(list_1)
# Out:
# [1, 3, 'hello', [5, 6, 7], None, <function func at 0x10a94b600>, 'new item']
# [1, 3, 'hello']
# [1, 3, 'hello', [5, 6, 'world'], None, <function func at 0x10a94b600>, 'new item']

# %% [markdown]
# - стрічку можна розкласти в колекцію по символах

# %%
s = "Hello"
list_s = list(s)
print(list_s)
s2 = '\n'
print("Це змінна з пустою стрічкою:", s2, "її довжина:", len(s2))
print(s2.join(list_s))
# Out:
# ['H', 'e', 'l', 'l', 'o']
# Це змінна з пустою стрічкою:
#  її довжина: 1
# H
# e
# l
# l
# o

# %% [markdown]
# - тепер розглянемо tuples, які є immutable колекціями

# %%
t = tuple([1, 2, 3, 1, 2, 3]) # перетворення списку у кортеж
print( t )
t2 = (1, 2.0, 3, "hello", 4.5, (5, 6, 7), None, func) # кортеж (tuple) - immutable колекція
print(t2)
a = t.count(1)
print(len(t), a, t.index(3))
# Out:
# (1, 2, 3, 1, 2, 3)
# (1, 2.0, 3, 'hello', 4.5, (5, 6, 7), None, <function func at 0x10a94b600>)
# 6 2 2

# %% [markdown]
# ### Приклад: різниця між list та tuple на практиці
# - list можна змінювати (додавати, видаляти, змінювати елементи), а tuple — ні.
# - Наприклад, список покупок з магазину краще зберігати як list, бо він може змінюватись.
# - А координати точки на площині (x, y) зручно зберігати як tuple, бо вони не змінюються.
# - можна tuple перетворити у list і тоді змінити

# %%
# Список покупок (list) — змінюється
shopping_list = ["хліб", "молоко", "яйця"]
print("Початковий список:", shopping_list)
shopping_list.append("сир") # додаємо новий товар
shopping_list[0] = "батон" # змінюємо перший елемент
print("Оновлений список:", shopping_list)

# Координати точки (tuple) — не змінюється
point = (10, 20)
print("Координати точки:", point)
try:
    point[0] = 15 # спроба змінити координату
except TypeError as e:
    print("Помилка:", e)
# Out:
# Початковий список: ['хліб', 'молоко', 'яйця']
# Оновлений список: ['батон', 'молоко', 'яйця', 'сир']
# Координати точки: (10, 20)
# Помилка: 'tuple' object does not support item assignment

# %% [markdown]
# ## розглядаємо колекцію Set
# - кожен елементв в колекції є унікальним, тому Set - це унікальна колекція
# - в багатьох мовах програмування, пошук унікальних елементів, це завжди якийсь алгоритм
# - Set не гарантує що дані будуть впорядковані
# - це просто куча унікальних значень з яких ми можемо по одному вибирати
# - ми не можемо мати в Set інші колекції, але можна мати просто типи int str

# %%
s = {1, 2, 3, 1, 2, 3} # множина (set) - унікальні значення
print(len(s))
l = [1, int(2), 3, "1", float(2), 3] 
# список (list) - можуть бути дублікати
s = set(l)
print("Початкова колекція:", len(l), l, "Після перетворення в Set:", len(s), s)
i = 2
f = 2.0
# ми не можемо порівнювати напряму 1 is 1.0, бо це різні типи
# # у першому випадку i це вже int який присвоївся в неявному перетворенні
# # коли беремо просто величину 2 то це просто величина без перетворення в обєкт
print(type(i), type(2), type(f), type(2.0))
if i is f: 
    print("Порівнюємо на ідентичність і маємо: True")
else: 
    print("Порівнюємо на ідентичність і маємо: False")
# assert i is f, "2 не є 2.0" # це викличе помилку AssertionError
# Out:
# 3
# Початкова колекція: 6 [1, 2, 3, '1', 2.0, 3] Після перетворення в Set: 4 {1, 2, 3, '1'}
# <class 'int'> <class 'int'> <class 'float'> <class 'float'>
# Порівнюємо на ідентичність і маємо: False

# %% [markdown]
# ### Словники
# - Словники завжди мають пару з key:value (це один елемент словника)
# - ключі мають бути унікальними та ніколи не повторюватись
# - ключі можуть бути як цифрами що подібно до списків або словами (іменними позиціями)
# - дата завжди унікальний ключ
# - словники повністю емулюють формат JSON

# %%
d = {"name": 1, 0: "Нуль", 1: 1, "Один": 1, 0: "Перевизначив"}
print(d)
d["Нуль"] = 0
print(d)
print(d[0], d["Нуль"])

Student = {"Прізвище": ["Б", "А"], "Імя": ["Богдан", "Василь"]}
print(Student["Прізвище"][0], Student["Імя"][0])
d.pop(0)
print(d)
# Out:
# {'name': 1, 0: 'Перевизначив', 1: 1, 'Один': 1}
# {'name': 1, 0: 'Перевизначив', 1: 1, 'Один': 1, 'Нуль': 0}
# Перевизначив 0
# Б Богдан
# {'name': 1, 1: 1, 'Один': 1, 'Нуль': 0}

# %% [markdown]
# - ми можемо виділити набір з одакових ключів або лише їх значень
# - робота з словниками, додавання, видалення елементів та робота з ними
# - ключі мають бути унікальними, тому використовуємо прості типи даних
# - значення можуть бути будь-якого типу, але доступ до них зберігається відповідно до типу (якщо словники то по ключах, якщо списки - індекси)

# %%
print(d.keys(), d.values())
# Out:
# dict_keys(['name', 1, 'Один', 'Нуль']) dict_values([1, 1, 1, 0])

# %% [markdown]
# ## Форматування виводу
# - декілька методів форматування тексту для виводу
# - використовуємо властивості функції print
# - використовувати властивості стрічок (конкатенацію) відформатувати стрічку до того як ми її - иведемо
# - використати методи format в стрічках

# %%
a = 10
print("Привіт", "Нас", a, "Ми", "почали", "вивчати", "Python")
start = "Привіт"
middle = "Нас"
end = "Ми почали вивчати Python"
final_string = start + " " + middle + " " + str(a) + " " + end
print(final_string)
# це робиться коли є декілька виводів, наприклад stdout і log файл
message = "1. Статус виконання: " + final_string
print("1. Статус виконання: " + final_string)
print(message)
s = "1. Статус виконання: {} {} <<{}>> {}".format(a, a, middle, a)
print(s)
# позиційна вставка дозволяє використовувати один і той же аргумент декілька разів
s2 = "1. Статус виконання: {0} {0} <<{1}>> {0}".format(a, middle)
print(s2)
f = 12.3456789
s3 = "різати стрічки {1:.3s} або обмежувати числа {0:.2f}".format(f, "HelloWorld"[4:7])
print(s3)
s4 = "Вивід: %.2s %.2f" % ("Hello", 12.0003) 
print(s4)
d = {"code": 200, "status": "успішно"}
s5 = "Статус: {status}, код: {code}".format(**d)
print(s5)
s6 = f"Статус: {a}, код: {d['code']}, число: {f:.3f}, стрічка: {'HelloWorld'[4:7]}"
print(s6)
for s in ["a", "ab", "abc", "abcd"]: 
    template = f"Початок: |{s:<10}|" 
    print(template)
# Out:
# Привіт Нас 10 Ми почали вивчати Python
# Привіт Нас 10 Ми почали вивчати Python
# 1. Статус виконання: Привіт Нас 10 Ми почали вивчати Python
# 1. Статус виконання: Привіт Нас 10 Ми почали вивчати Python
# 1. Статус виконання: 10 10 <<Нас>> 10
# 1. Статус виконання: 10 10 <<Нас>> 10
# різати стрічки oWo або обмежувати числа 12.35
# Вивід: He 12.00
# Статус: успішно, код: 200
# Статус: 10, код: 200, число: 12.346, стрічка: oWo
# Початок: |a         |
# Початок: |ab        |
# Початок: |abc       |
# Початок: |abcd      |

# %% [markdown]
# ## Вбудовані константи
# - None - важлива константа яка означає ніщо
# - ніколи не можна перевизначати ні константи ні вбудовані функції

# %%
def fun(): 
    return NotImplemented
fun()
def fun(): 
    return
print(fun())
l = [1, 6, 3, 9, 1]
print(l)
print(l.sort())
print(l)
#None = "Правда"

# False = 1 # це неможна, буде помилка
false = True
print("Чому це не є рівним", false == False, "?")
# Out:
# None
# [1, 6, 3, 9, 1]
# None
# [1, 1, 3, 6, 9]
# Чому це не є рівним False ?

# %% [markdown]
# ## Вбудовані функції
# - Пайтон дозволяє перевизначати назви функцій, але це потім ломає їх виконання

# %%
#print = "123"
#Якщо ми виконаємо цей код, то отримаємо помилку, бо print це вбудована функція
print("щось")

for i in map(min, ["asdf", [1,2,3,124]]):
    print(i)

FOR = 1 # але не можна робити for з малої букви

print(any([1!=2, 5=="5", 0 == False]))
# Out:
# щось
# a
# 1
# True

# %% [markdown]
# ## Цикли
# - цикли дозволяють повторити виконання певної операції
# - є тільки два цикли, for та while-
# - for - призначений для ітерації по елементах
# - while - умовний цикл, призначений для умовних виконання тіла циклу

# %%
s = "стрічка для виводу"
print(s + "Далі")
print(s + "Наступний рядок" )
print(s + "Далі")

for i in ["Далі", "Наступний рядок", "Далі"]:
    print(s + i)
# Out:
# стрічка для виводуДалі
# стрічка для виводуНаступний рядок
# стрічка для виводуДалі
# стрічка для виводуДалі
# стрічка для виводуНаступний рядок
# стрічка для виводуДалі

# %%
for i in range(5):
    print(s + str(i) + "Вивід for ", i)

i = 0 # лічильник
while i < 5:
    print(s + str(i) + "Вивід while", i)
    i += 1

al = ["a", "b", "c", "d", "e"]
for s in al:
    print(f"В циклі for вивели = {s}")

while al: # поки список не порожній
    print(f"В циклі while вивели = {al.pop(0)}")

#ми робимо переініціалізацію списку бо він став порожнім через поп
al = ["a", "b", "c", "d", "e"]
i = 0
while i < len(al):
    print(f"В циклі while з індексом вивели = {al[i]}")
    i += 1
# Out:
# стрічка для виводу0Вивід for  0
# стрічка для виводу1Вивід for  1
# стрічка для виводу2Вивід for  2
# стрічка для виводу3Вивід for  3
# стрічка для виводу4Вивід for  4
# стрічка для виводу0Вивід while 0
# стрічка для виводу1Вивід while 1
# стрічка для виводу2Вивід while 2
# стрічка для виводу3Вивід while 3
# стрічка для виводу4Вивід while 4
# В циклі for вивели = a
# В циклі for вивели = b
# В циклі for вивели = c
# В циклі for вивели = d
# В циклі for вивели = e
# В циклі while вивели = a
# В циклі while вивели = b
# В циклі while вивели = c
# В циклі while вивели = d
# В циклі while вивели = e
# В циклі while з індексом вивели = a
# В циклі while з індексом вивели = b
# В циклі while з індексом вивели = c
# В циклі while з індексом вивели = d
# В циклі while з індексом вивели = e

# %% [markdown]
# ### ЗАВДАННЯ
# - в нас є кубик і ми хочемо щоб випало число 6 (ми кидаємо кубик допоки не випадає 6)

# %%
import random

r = None
i = 1
while r != 6:
    r = random.randint(1, 6) # симулює кидання кубика
    print(f"{i}. Випало число на кубику: {r}")
    i += 1

for _ in range(20):
    r = random.randint(1, 6)
    print(f"{_+1}. Випало число на кубику: {r}")
    if r == 6:
        break
# Out:
# 1. Випало число на кубику: 2
# 2. Випало число на кубику: 5
# 3. Випало число на кубику: 5
# 4. Випало число на кубику: 5
# 5. Випало число на кубику: 1
# 6. Випало число на кубику: 3
# 7. Випало число на кубику: 2
# 8. Випало число на кубику: 6
# 1. Випало число на кубику: 2
# 2. Випало число на кубику: 4
# 3. Випало число на кубику: 2
# 4. Випало число на кубику: 2
# 5. Випало число на кубику: 6

# %% [markdown]
# ### ЗАВДАННЯ
# - ми маємо пачку M&Ms Мндс, ми хочемо взяти 5 цукерок і подивитись якого вони кольору

# %%
import random
mmds = ["червоний", "зелений", "жовтий", "фіолетовий", "помаранчевий"]
pack = 50 * mmds
random.shuffle(pack)
print(f"Упаковка містить {len(pack)} ммдс, {pack}")

for m in pack[1:6]:
    print(f"Витягнули ммдс: {m}")
# Out:
# Упаковка містить 250 ммдс, ['помаранчевий', 'червоний', 'фіолетовий', 'фіолетовий', 'зелений', 'фіолетовий', 'зелений', 'червоний', 'зелений', 'зелений', 'жовтий', 'жовтий', 'фіолетовий', 'жовтий', 'фіолетовий', 'фіолетовий', 'фіолетовий', 'фіолетовий', 'зелений', 'зелений', 'жовтий', 'жовтий', 'фіолетовий', 'червоний', 'зелений', 'зелений', 'помаранчевий', 'зелений', 'фіолетовий', 'зелений', 'фіолетовий', 'помаранчевий', 'помаранчевий', 'зелений', 'червоний', 'червоний', 'зелений', 'червоний', 'червоний', 'зелений', 'помаранчевий', 'помаранчевий', 'червоний', 'зелений', 'жовтий', 'зелений', 'зелений', 'фіолетовий', 'жовтий', 'помаранчевий', 'зелений', 'помаранчевий', 'зелений', 'помаранчевий', 'помаранчевий', 'червоний', 'фіолетовий', 'помаранчевий', 'помаранчевий', 'помаранчевий', 'червоний', 'червоний', 'жовтий', 'жовтий', 'помаранчевий', 'зелений', 'жовтий', 'жовтий', 'зелений', 'помаранчевий', 'помаранчевий', 'зелений', 'червоний', 'фіолетовий', 'червоний', 'червоний', 'червоний', 'фіолетовий', 'жовтий', 'зелений', 'фіолетовий', 'жовтий', 'червоний', 'жовтий', 'зелений', 'жовтий', 'фіолетовий', 'жовтий', 'жовтий', 'червоний', 'жовтий', 'жовтий', 'зелений', 'червоний', 'помаранчевий', 'червоний', 'жовтий', 'фіолетовий', 'жовтий', 'зелений', 'помаранчевий', 'помаранчевий', 'жовтий', 'помаранчевий', 'фіолетовий', 'червоний', 'фіолетовий', 'фіолетовий', 'червоний', 'фіолетовий', 'фіолетовий', 'червоний', 'фіолетовий', 'жовтий', 'зелений', 'помаранчевий', 'червоний', 'червоний', 'помаранчевий', 'зелений', 'жовтий', 'фіолетовий', 'червоний', 'червоний', 'фіолетовий', 'помаранчевий', 'помаранчевий', 'фіолетовий', 'фіолетовий', 'жовтий', 'помаранчевий', 'фіолетовий', 'зелений', 'зелений', 'помаранчевий', 'зелений', 'жовтий', 'жовтий', 'фіолетовий', 'помаранчевий', 'зелений', 'червоний', 'помаранчевий', 'зелений', 'зелений', 'жовтий', 'помаранчевий', 'фіолетовий', 'червоний', 'жовтий', 'жовтий', 'помаранчевий', 'червоний', 'зелений', 'жовтий', 'зелений', 'помаранчевий', 'червоний', 'червоний', 'помаранчевий', 'фіолетовий', 'зелений', 'зелений', 'фіолетовий', 'фіолетовий', 'фіолетовий', 'фіолетовий', 'помаранчевий', 'жовтий', 'зелений', 'фіолетовий', 'червоний', 'помаранчевий', 'фіолетовий', 'зелений', 'помаранчевий', 'фіолетовий', 'помаранчевий', 'червоний', 'зелений', 'червоний', 'жовтий', 'зелений', 'жовтий', 'червоний', 'зелений', 'жовтий', 'помаранчевий', 'червоний', 'жовтий', 'червоний', 'жовтий', 'фіолетовий', 'червоний', 'помаранчевий', 'зелений', 'жовтий', 'фіолетовий', 'фіолетовий', 'червоний', 'червоний', 'жовтий', 'помаранчевий', 'зелений', 'жовтий', 'червоний', 'червоний', 'червоний', 'жовтий', 'фіолетовий', 'зелений', 'жовтий', 'червоний', 'зелений', 'помаранчевий', 'жовтий', 'фіолетовий', 'помаранчевий', 'червоний', 'фіолетовий', 'помаранчевий', 'фіолетовий', 'фіолетовий', 'червоний', 'помаранчевий', 'помаранчевий', 'червоний', 'жовтий', 'червоний', 'жовтий', 'помаранчевий', 'помаранчевий', 'жовтий', 'жовтий', 'фіолетовий', 'зелений', 'помаранчевий', 'фіолетовий', 'жовтий', 'зелений', 'червоний', 'помаранчевий', 'помаранчевий', 'помаранчевий', 'червоний', 'фіолетовий', 'зелений', 'жовтий', 'жовтий', 'зелений']
# Витягнули ммдс: червоний
# Витягнули ммдс: фіолетовий
# Витягнули ммдс: фіолетовий
# Витягнули ммдс: зелений
# Витягнули ммдс: фіолетовий

# %%
i = 0
while i < 5:
    print(f"Витягнули ммдс: {pack[i]}")
    i += 1
# Out:
# Витягнули ммдс: помаранчевий
# Витягнули ммдс: червоний
# Витягнули ммдс: фіолетовий
# Витягнули ммдс: фіолетовий
# Витягнули ммдс: зелений

# %% [markdown]
# - є два зарезервовані слова break та continue
# Завдання
# - ми їмо M&Ds і відкладаємо червоні, а якщо нам попалась зелена ми перескаємо їсти

# %%
for m in pack:
    print(f"Витягнули ммдс: {m}")
    if m == "червоний":
        continue
    print(f"Зїдали ммдс: {m}")
    if m == "зелений":
        print("Більше не їмо, бо зелений!")
        break
# Out:
# Витягнули ммдс: помаранчевий
# Зїдали ммдс: помаранчевий
# Витягнули ммдс: червоний
# Витягнули ммдс: фіолетовий
# Зїдали ммдс: фіолетовий
# Витягнули ммдс: фіолетовий
# Зїдали ммдс: фіолетовий
# Витягнули ммдс: зелений
# Зїдали ммдс: зелений
# Більше не їмо, бо зелений!

# %%
pack = 10 * mmds
for i in range(1, 10):
    while i < len(pack):
        print(f"{i}. Витягнули ммдс: {pack.pop()}")
    print("Закінчили їсти")
# Out:
# 1. Витягнули ммдс: помаранчевий
# 1. Витягнули ммдс: фіолетовий
# 1. Витягнули ммдс: жовтий
# 1. Витягнули ммдс: зелений
# 1. Витягнули ммдс: червоний
# 1. Витягнули ммдс: помаранчевий
# 1. Витягнули ммдс: фіолетовий
# 1. Витягнули ммдс: жовтий
# 1. Витягнули ммдс: зелений
# 1. Витягнули ммдс: червоний
# 1. Витягнули ммдс: помаранчевий
# 1. Витягнули ммдс: фіолетовий
# 1. Витягнули ммдс: жовтий
# 1. Витягнули ммдс: зелений
# 1. Витягнули ммдс: червоний
# 1. Витягнули ммдс: помаранчевий
# 1. Витягнули ммдс: фіолетовий
# 1. Витягнули ммдс: жовтий
# 1. Витягнули ммдс: зелений
# 1. Витягнули ммдс: червоний
# 1. Витягнули ммдс: помаранчевий
# 1. Витягнули ммдс: фіолетовий
# 1. Витягнули ммдс: жовтий
# 1. Витягнули ммдс: зелений
# 1. Витягнули ммдс: червоний
# 1. Витягнули ммдс: помаранчевий
# 1. Витягнули ммдс: фіолетовий
# 1. Витягнули ммдс: жовтий
# 1. Витягнули ммдс: зелений
# 1. Витягнули ммдс: червоний
# 1. Витягнули ммдс: помаранчевий
# 1. Витягнули ммдс: фіолетовий
# 1. Витягнули ммдс: жовтий
# 1. Витягнули ммдс: зелений
# 1. Витягнули ммдс: червоний
# 1. Витягнули ммдс: помаранчевий
# 1. Витягнули ммдс: фіолетовий
# 1. Витягнули ммдс: жовтий
# 1. Витягнули ммдс: зелений
# 1. Витягнули ммдс: червоний
# 1. Витягнули ммдс: помаранчевий
# 1. Витягнули ммдс: фіолетовий
# 1. Витягнули ммдс: жовтий
# 1. Витягнули ммдс: зелений
# 1. Витягнули ммдс: червоний
# 1. Витягнули ммдс: помаранчевий
# 1. Витягнули ммдс: фіолетовий
# 1. Витягнули ммдс: жовтий
# 1. Витягнули ммдс: зелений
# Закінчили їсти
# Закінчили їсти
# Закінчили їсти
# Закінчили їсти
# Закінчили їсти
# Закінчили їсти
# Закінчили їсти
# Закінчили їсти
# Закінчили їсти

# %% [markdown]
# - однострічкові цикли, list comprehantions - існує лише для циклу for

# %%
f = [f"В циклі for вивели = {s}" for s in range(5)]
print(f)
# Out:
# ['В циклі for вивели = 0', 'В циклі for вивели = 1', 'В циклі for вивели = 2', 'В циклі for вивели = 3', 'В циклі for вивели = 4']

# %% [markdown]
# # Розгалуження
# - умовний оператор if - це тернарна операція
# - найчастіше його задають у скороченому вигляді просто if

# %%
a = random.choice([True, False])
if a:
    print("Це правда")
else:
    print("Це не правда")

# однострічковий if
print("Це правда" if a else "Це не правда")
# Out:
# Це не правда
# Це не правда

# %%
g = ["червоний", "зелений", "жовтий"]
for j in range(10):
    i = random.randint(0, 2)
    if g[i] == "червоний":
        print("Стоп, червоний!")
    print("Все добре їдемо далі")
# Out:
# Стоп, червоний!
# Все добре їдемо далі
# Все добре їдемо далі
# Все добре їдемо далі
# Стоп, червоний!
# Все добре їдемо далі
# Стоп, червоний!
# Все добре їдемо далі
# Все добре їдемо далі
# Все добре їдемо далі
# Все добре їдемо далі
# Стоп, червоний!
# Все добре їдемо далі
# Стоп, червоний!
# Все добре їдемо далі

# %% [markdown]
# - а також ми можемо записати в одиному рядку цикл і умову розгалуження
# Завдання
# - їмо M&Ds але відкладаємо всі зелені

# %%
pack = 10 * mmds
k = [print(f"Ми зїли {m}") for m in pack if m != "зелений"]
k
# Out:
# Ми зїли червоний
# Ми зїли жовтий
# Ми зїли фіолетовий
# Ми зїли помаранчевий
# Ми зїли червоний
# Ми зїли жовтий
# Ми зїли фіолетовий
# Ми зїли помаранчевий
# Ми зїли червоний
# Ми зїли жовтий
# Ми зїли фіолетовий
# Ми зїли помаранчевий
# Ми зїли червоний
# Ми зїли жовтий
# Ми зїли фіолетовий
# Ми зїли помаранчевий
# Ми зїли червоний
# Ми зїли жовтий
# Ми зїли фіолетовий
# Ми зїли помаранчевий
# Ми зїли червоний
# Ми зїли жовтий
# Ми зїли фіолетовий
# Ми зїли помаранчевий
# Ми зїли червоний
# Ми зїли жовтий
# Ми зїли фіолетовий
# Ми зїли помаранчевий
# Ми зїли червоний
# Ми зїли жовтий
# Ми зїли фіолетовий
# Ми зїли помаранчевий
# Ми зїли червоний
# Ми зїли жовтий
# Ми зїли фіолетовий
# Ми зїли помаранчевий
# Ми зїли червоний
# Ми зїли жовтий
# Ми зїли фіолетовий
# Ми зїли помаранчевий
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %% [markdown]
# # Виловлювання помилок
# - це написання коду, який правильно опрацює помилку якщо вона виникне

# %%
for i in range(10):
    print(i)
    n = random.randint(0, 4)
    try:
        z = i/n
        print(f"Згенерували випадкове число: {n} та робимо ділення: {z}")
    except (ZeroDivisionError, TypeError) as e:
        print("Помилка: ділення на нуль!", e)
        z = 0
    finally:
        print(f"Цей блок виконається в будь-якому разі, z = {z}")
# Out:
# 0
# Помилка: ділення на нуль! division by zero
# Цей блок виконається в будь-якому разі, z = 0
# 1
# Згенерували випадкове число: 2 та робимо ділення: 0.5
# Цей блок виконається в будь-якому разі, z = 0.5
# 2
# Помилка: ділення на нуль! division by zero
# Цей блок виконається в будь-якому разі, z = 0
# 3
# Згенерували випадкове число: 4 та робимо ділення: 0.75
# Цей блок виконається в будь-якому разі, z = 0.75
# 4
# Помилка: ділення на нуль! division by zero
# Цей блок виконається в будь-якому разі, z = 0
# 5
# Згенерували випадкове число: 3 та робимо ділення: 1.6666666666666667
# Цей блок виконається в будь-якому разі, z = 1.6666666666666667
# 6
# Помилка: ділення на нуль! division by zero
# Цей блок виконається в будь-якому разі, z = 0
# 7
# Згенерували випадкове число: 3 та робимо ділення: 2.3333333333333335
# Цей блок виконається в будь-якому разі, z = 2.3333333333333335
# 8
# Помилка: ділення на нуль! division by zero
# Цей блок виконається в будь-якому разі, z = 0
# 9
# Згенерували випадкове число: 3 та робимо ділення: 3.0
# Цей блок виконається в будь-якому разі, z = 3.0

# %% [markdown]
# # Контекст менеджери
# - використовуються для узгодженої роботи з певними системами (бази даних, робота з файлами, в тестуванні коли очікуємо якоїсь операції)

# %%
# f - це точка входу в файл
with open("test.txt", "w", encoding="utf-8") as f:
    f.write("Це тестовий файл\n")
    f.write("Другий рядок\n")
    f.write("Третій рядок\n")
print("Це вже поза блоком with, файл автоматично закритий")
# Out:
# Це вже поза блоком with, файл автоматично закритий

# %%
f = open("text.txt", "wt+", encoding="utf-8")
f.write("Це тестовий файл\n")
#f.close()
# Out:
# 17

# %%
d = open("text.txt", "wt+", encoding="utf-8")
d.write("На початку файл був пустий\n")
d.close()

# %%
f.close()

# %% [markdown]
# # Функції та безіменні функції
# - функції дозволяють зменшити дублювання коду
# - під функцією ми можемо розуміти блок коду якому ми дали назву
# - функція також є обєктом в пайтоні
# - імена функцій повинні відображати що вона буде робити - і ще більше це важливо для АІ
# - функція може приймати аргументи та повертати значення

# %%
def print_few_lines_function(text="За замовчуванням"):
    print(f"Line 1 - {text}")
    print(f"Line 2 - {text}")
    print(f"Line 3 - {text}")

def write_strings_to_file(lines:str, filename="text.txt"):
    """Записує рядки у файл, кожен рядок з нового рядка"""
    with open(filename, "w", encoding="utf-8") as file:
        for line in lines.split("\n"):
            file.write(line + "\n")
    return "Успішно записано"

print(type(print_few_lines_function))
print_few_lines_function()
print_few_lines_function("Передали аргумент")

pr = write_strings_to_file("Перший рядок\nДругий рядок\nТретій рядок")
print(f"Результат виклику функції: {pr}")
# Out:
# <class 'function'>
# Line 1 - За замовчуванням
# Line 2 - За замовчуванням
# Line 3 - За замовчуванням
# Line 1 - Передали аргумент
# Line 2 - Передали аргумент
# Line 3 - Передали аргумент
# Результат виклику функції: Успішно записано

# %% [markdown]
# - існують дуже прості функцї які просто повертають значення
# - для простих випадків де нам потрібно просто повершути результат операції існують так звані безіменні функції (або lambdas)

# %%
def sum_two_numbers(a: int, b: int) -> int:
    """Повертає суму двох чисел"""
    return a + b

result = sum_two_numbers(5, 10)
print(f"Сума двох чисел: {result}")

result = lambda a, b: a + b
r2 = lambda a, b: a * b

print(type(sum_two_numbers), type(result), type(r2))
print(f"Сума двох чисел через lambda: {result(5, 10)}")
print(f"Добуток двох чисел через lambda: {r2(5, 10)}")
# Out:
# Сума двох чисел: 15
# <class 'function'> <class 'function'> <class 'function'>
# Сума двох чисел через lambda: 15
# Добуток двох чисел через lambda: 50
